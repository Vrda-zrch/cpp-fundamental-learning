# %% [markdown]
# <a href="https://colab.research.google.com/github/Vrda-zrch/cpp-fundamental-learning/blob/main/Simple_Phyton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Firts Materials About Phyton

# %%
a=2
b=3
c=a+b
print (c)
# Out:
# 5
