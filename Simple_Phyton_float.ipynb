# %% [markdown]
# <a href="https://colab.research.google.com/github/Vrda-zrch/cpp-fundamental-learning/blob/main/Simple_Phyton_float.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Type data

# %%
print(3.14)
# Out:
# 3.14
